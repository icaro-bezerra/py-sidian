# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/100 Days Of Data Engineering - Make A Copy And Use As You Need - Sheet1.csv")
df
# Out:
#     Unnamed: 0                                      100 Days Note Unnamed: 2  \
# 0          NaN  100 days is just a little over 3 months and I ...        NaN
# 1          NaN                                                NaN        NaN
# 2          NaN                                                NaN        NaN
# 3          Day                                               Task      Notes
# 4        Day 1  For day one, what I reccomend is taking the ti...        NaN
# ..         ...                                                ...        ...
# 99      Day 96                                                NaN        NaN
# 100     Day 97                                                NaN        NaN
# 101     Day 98                                                NaN        NaN
# 102     Day 99                                                NaN        NaN
# 103    Day 100  Write a blog, post or create a github repo to ...        NaN
#
# ...

# %%
df = df.rename(columns={'Unnamed: 0':'day','100 Days Note':'task','Unnamed: 2':'notes','Unnamed: 3':'category','Unnamed: 4':'LinkA','Unnamed: 5':'LinkB','Unnamed: 6':'LinkC','Unnamed: 7':'LinkD'})

# %%
df.keys()
# Out:
# Index(['day', 'task', 'notes', 'category', 'LinkA', 'LinkB', 'LinkC', 'LinkD'], dtype='object')

# %%
df = df[df["day"].str.contains("Day") == True]
df
df = df.drop([3])
df
# Out:
#          day                                               task notes  \
# 4      Day 1  For day one, what I reccomend is taking the ti...   NaN
# 5      Day 2  1. Downloading SQL Server And Creating A Table...   NaN
# 6      Day 3  1. SQL Interview Tips\n2.Solving More Problems...   NaN
# 7      Day 4  1. Partition By\n2. CTE (Common Table Expressi...   NaN
# 8      Day 5  1. Loops Strings And Tuples\n2. Functions\n3. ...   NaN
# ..       ...                                                ...   ...
# 99    Day 96                                                NaN   NaN
# 100   Day 97                                                NaN   NaN
# 101   Day 98                                                NaN   NaN
# 102   Day 99                                                NaN   NaN
# 103  Day 100  Write a blog, post or create a github repo to ...   NaN
#
#                               category  \
# 4    Take a moment to write your goals
# 5                                  SQL
# ...

# %%
df
# Out:
#          day                                               task notes  \
# 4      Day 1  For day one, what I reccomend is taking the ti...   NaN
# 5      Day 2  1. Downloading SQL Server And Creating A Table...   NaN
# 6      Day 3  1. SQL Interview Tips\n2.Solving More Problems...   NaN
# 7      Day 4  1. Partition By\n2. CTE (Common Table Expressi...   NaN
# 8      Day 5  1. Loops Strings And Tuples\n2. Functions\n3. ...   NaN
# ..       ...                                                ...   ...
# 99    Day 96                                                NaN   NaN
# 100   Day 97                                                NaN   NaN
# 101   Day 98                                                NaN   NaN
# 102   Day 99                                                NaN   NaN
# 103  Day 100  Write a blog, post or create a github repo to ...   NaN
#
#                               category  \
# 4    Take a moment to write your goals
# 5                                  SQL
# ...

# %%
df = df.reset_index()
df = df.drop('index',axis=1)
df = df.replace(np.nan, None)

# %%
df.to_parquet('../data/task.parquet')

# %%
df.keys
# Out:
# <bound method NDFrame.keys of         day                                               task notes  \
# 0     Day 1  For day one, what I reccomend is taking the ti...  None
# 1     Day 2  1. Downloading SQL Server And Creating A Table...  None
# 2     Day 3  1. SQL Interview Tips\n2.Solving More Problems...  None
# 3     Day 4  1. Partition By\n2. CTE (Common Table Expressi...  None
# 4     Day 5  1. Loops Strings And Tuples\n2. Functions\n3. ...  None
# ..      ...                                                ...   ...
# 95   Day 96                                               None  None
# 96   Day 97                                               None  None
# 97   Day 98                                               None  None
# 98   Day 99                                               None  None
# 99  Day 100  Write a blog, post or create a github repo to ...  None
#
#                              category  \
# 0   Take a moment to write your goals
# ...
